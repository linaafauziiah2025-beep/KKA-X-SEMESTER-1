# %% [markdown]
# <a href="https://colab.research.google.com/github/linaafauziiah2025-beep/KKA-X-SEMESTER-1/blob/main/3_Aplikasi_sederhana_Lina_F_X_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
jari = int(input("Masukkan jari-jari dari tabung (cm) : ") )
tinggi = int(input (" Masukkan tinggi dari tabung (cm) :") )

volume = 22/7 * jari * jari * tinggi

print(f"\n volume dari tabung yaitu {volume} cm^3")
# Out:
# Masukkan jari-jari dari tabung (cm) : 7
#  Masukkan tinggi dari tabung (cm) :12
#
#  volume dari tabung yaitu 1848.0 cm^3
