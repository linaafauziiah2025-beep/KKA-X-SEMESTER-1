# %% [markdown]
# <a href="https://colab.research.google.com/github/linaafauziiah2025-beep/KKA-X-SEMESTER-1/blob/main/1_Fungsi_print_Lina_F_X_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Nama: Lina Fauziah\nkelas: X.8\nNo.Absen:14")
# Out:
# Nama: Lina Fauziah
# kelas: X.8
# No.Absen:14

# %% [markdown]
# #Menampilkan Teks Bebas

# %%
print("Helo world!")
# Out:
# Helo world!

# %% [markdown]
# #Menampilkan Nilai Variabel

# %%
usia = 14

print(usia)
# Out:
# 14

# %%
Bb =60
print(Bb)
# Out:
# 60

# %%
Nama ="Lina Fauziah"

print(Nama)
# Out:
# Lina Fauziah

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel

# %%
print(f"perkenalkan nama saya {Nama}.")
# Out:
# perkenalkan nama saya Lina Fauziah.

# %%
print("perkenalkan nama saya " + Nama)
# Out:
# perkenalkan nama saya Lina Fauziah

# %%
print(f"menampilkan berat badan saya {Bb} kg.")
# Out:
# menampilkan berat badan saya 60 kg.

# %%
print("berat badan saya " + str(Bb) + " kg.")
# Out:
# berat badan saya 60 kg.

# %%
print("berat badan saya " , Bb , "kg.")
# Out:
# berat badan saya  60 kg.

# %% [markdown]
# #Escape Character

# %%
print("Nama:Lina Fauziah\nkelas:X.8\nNo.Absen:14 ")
# Out:
# Nama:Lina Fauziah
# kelas:X.8
# No.Absen:14

# %%
print("""Nama\t\t:Lina Fauziah
kelas\t\t:X.8
No.Absen\t:14 """)
# Out:
# Nama		:Lina Fauziah
# kelas		:X.8
# No.Absen	:14

# %%
print("Nama: ja'far shodiq\nkelas: X.8\nNo.Absen: 29")
# Out:
# Nama: ja'far shodiq
# kelas: X.8
# No.Absen: 29

# %%
print('Nama: ja\'far shodiq\nkelas: X.8\nNo.Absen: 29')
# Out:
# Nama: ja'far shodiq
# kelas: X.8
# No.Absen: 29

# %%
print("Lokasi File Tugas KKA:Local Disk C:\\KKA\\Tugas Shinta")
# Out:
# Lokasi File Tugas KKA:Local Disk C:\KKA\Tugas Shinta

# %% [markdown]
# #Parameter Fungsi print ()

# %%
Tahun = 2025
Bulan = "Agustus"
Tanggal = 23

print(Tahun, Bulan, Tanggal, sep="-")
# Out:
# 2025-Agustus-23

# %%
nama_depan = "Lina"
nama_belakang = "Fauziah"

print(nama_depan, end=" ")
print(nama_belakang)
# Out:
# Lina Fauziah

# %%
nama_siswa_1="Dinda"

nama_siswa_2="Aurin"

nama_siswa_3="Lisaan"

print(nama_siswa_3, nama_siswa_2, nama_siswa_3, nama_siswa_1, sep= '/')
# Out:
# Lisaan/Aurin/Lisaan/Dinda

# %%
nama_siswa_4="Azkal"
nama_siswa_5="Hasim"
nama_siswa_6="Chilmi"
nama_siswa_7="Nova"

print(nama_siswa_6, end="~")
print(nama_siswa_4)
print(nama_siswa_5, end="-")
print(nama_siswa_7)
print(nama_siswa_4, end="/")
print(nama_siswa_7, end="&")
print(nama_siswa_5)
# Out:
# Chilmi~Azkal
# Hasim-Nova
# Azkal/Nova&Hasim

# %% [markdown]
# Nama: Lina Fauziah
#
# Kelas: X.8
#
# Absen: 14
